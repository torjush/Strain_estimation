# %%
# %load_ext autoreload
# %autoreload 2

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
# Be able to import from src folder
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
import sys
sys.path.append(os.path.join(PROJ_ROOT, 'src'))

import misc.notebookHelpers

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

plt.rcParams['figure.figsize'] = (10, 10)
# Out:
# /Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation

# %%
data_path = os.path.join(PROJ_ROOT, 'data/processed/mitral_point_labeled/')

# %%
data_path
# Out:
# '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/'

# %%
h5files = glob.glob(os.path.join(data_path, '*/*.h5'))
h5files
# Out:
# ['/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53BBRO2.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53BCBO6.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53BCN8A.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53BDC0E.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53BDN8I.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53BE4GM.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53E6MSA.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53E71CE.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53E7E4I.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53E7KCM.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53E8SCQ.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p1/I53E95KU.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I5987882.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I5987E06.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I5987R8A.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I598830E.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I598940I.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I5989C0M.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I59C15SM.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I59C1ECQ.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I59C1S4U.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I59C2552.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I59C2N56.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p2/I59C2T5A.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599F482.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599FOO6.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599G5GA.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599GGOE.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599GS0I.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599H20M.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I59D2GQM.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I59D2MAQ.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I59D2S2U.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I59D31J2.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I59D37J6.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I59D3DRA.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EDSLO2.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EDSU06.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EDTB0A.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EDTL0E.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EE038I.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EE0I8M.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EGD92E.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EGE0QI.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EGE5QM.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EGECQQ.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EGETAU.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p4/I5EGF4J2.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p5/I5FCAP82.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p5/I5FCB806.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p5/I5FCC48A.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p5/I5FCCBGE.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p5/I5FCCNGI.h5',
#  '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p5/I5FCD28M.h5']

# %%
os.path.join(data_path, '*/*.h5')
# Out:
# '/Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/*/*.h5'

# %% [markdown]
# Pick a random file and see if we can find a suitable point

# %%
file_idx = np.random.randint(0, len(h5files))
h5file = h5files[file_idx]

# %%
data = h5py.File(h5file)
list(data.keys())
# Out:
# ['TVI', 'ecg', 'tissue']

# %%
video, fps = misc.notebookHelpers.video_and_fps_from_h5py(data, 'b-mode')
tvi_video = np.transpose(data['TVI/data'], [2, 1, 0])

# %% [markdown]
# Check that we can view the mitral points and that they make sense

# %%
misc.notebookHelpers.ultraSoundAnimation(video, fps=fps, points=data['tissue/mitral_points'])
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Select the first frame, and search for points below the mitral points to track

# %%
frame = video[0, :, :]
mitral_points = data['tissue/mitral_points'][0, :, :]

# %%
list(data['tissue'].keys())
# Out:
# ['data',
#  'dirx',
#  'diry',
#  'ds_labels',
#  'mitral_points',
#  'origin',
#  'pixelsize',
#  'times']

# %%
plt.imshow(frame, cmap='Greys_r')
plt.scatter(mitral_points[0, 1], mitral_points[0, 0], color='red')
plt.scatter(mitral_points[1, 1], mitral_points[1, 0], color='red')

# %%
data['tissue/pixelsize'][:]
# Out:
# array([0.0005, 0.0005])

# %%
def cm_to_pixel(num_cm, data_file, dim):
    pixel_size_cm = data_file['tissue/pixelsize'][dim] * 100
    return int(round(num_cm / pixel_size_cm))

# %%
search_box_left = np.array([[mitral_points[0, 0] + cm_to_pixel(2.5, data, 1), mitral_points[0, 0] + cm_to_pixel(4.5, data, 1)],
                            [mitral_points[0, 1] - cm_to_pixel(1, data, 0), mitral_points[0, 1] + cm_to_pixel(1, data, 0)]])

# %%
search_box_left
# Out:
# array([[148, 188],
#        [120, 160]])

# %%
plt.imshow(frame, cmap='Greys_r')
plt.scatter(mitral_points[0, 1], mitral_points[0, 0], color='red')
plt.scatter(mitral_points[1, 1], mitral_points[1, 0], color='red')

rectangle = plt.Rectangle((search_box_left[1, 0], search_box_left[0, 0]), 
                           search_box_left[1, 1] - search_box_left[1, 0], 
                           search_box_left[0, 1] - search_box_left[0, 0], color='r', fill=False)
plt.gca().add_patch(rectangle)

# %%
left_search_region = frame[search_box_left[0, 0]:search_box_left[0, 1],
                           search_box_left[1, 0]:search_box_left[1, 1]]

# %%
mitral_points[0, 0]
# Out:
# 98

# %%
flattened_index = np.argmax(left_search_region)
segment_point_left = np.unravel_index(flattened_index, left_search_region.shape)
segment_point_left = np.array([segment_point_left[0] + search_box_left[0, 0], segment_point_left[1] + search_box_left[1, 0]])
segment_point_left
# Out:
# array([168, 125])

# %%
plt.imshow(frame, cmap='Greys_r')
plt.scatter(mitral_points[0, 1], mitral_points[0, 0], color='red')
plt.scatter(mitral_points[1, 1], mitral_points[1, 0], color='red')
plt.scatter(segment_point_left[1], segment_point_left[0], color='red')

# %%
search_box_right = np.array([[mitral_points[1, 0] + cm_to_pixel(2.5, data, 1), mitral_points[1, 0] + cm_to_pixel(4.5, data, 1)],
                            [mitral_points[1, 1] - cm_to_pixel(1, data, 0), mitral_points[1, 1] + cm_to_pixel(1, data, 0)]])

# %%
plt.imshow(frame, cmap='Greys_r')
plt.scatter(mitral_points[0, 1], mitral_points[0, 0], color='red')
plt.scatter(mitral_points[1, 1], mitral_points[1, 0], color='red')

rectangle = plt.Rectangle((search_box_left[1, 0], search_box_left[0, 0]), 
                           search_box_left[1, 1] - search_box_left[1, 0], 
                           search_box_left[0, 1] - search_box_left[0, 0], color='r', fill=False)
plt.gca().add_patch(rectangle)

rectangle = plt.Rectangle((search_box_right[1, 0], search_box_right[0, 0]), 
                           search_box_right[1, 1] - search_box_right[1, 0], 
                           search_box_right[0, 1] - search_box_right[0, 0], color='r', fill=False)
plt.gca().add_patch(rectangle)

# %%
right_search_region = frame[search_box_right[0, 0]:search_box_right[0, 1],
                           search_box_right[1, 0]:search_box_right[1, 1]]

# %%
flattened_index = np.argmax(right_search_region)
segment_point_right = np.unravel_index(flattened_index, right_search_region.shape)
segment_point_right = np.array([segment_point_right[0] + search_box_right[0, 0], segment_point_right[1] + search_box_right[1, 0]])
segment_point_right
# Out:
# array([143, 229])

# %%
plt.imshow(frame, cmap='Greys_r')
plt.scatter(mitral_points[0, 1], mitral_points[0, 0], color='red')
plt.scatter(mitral_points[1, 1], mitral_points[1, 0], color='red')
plt.scatter(segment_point_left[1], segment_point_left[0], color='red')
plt.scatter(segment_point_right[1], segment_point_right[0], color='red')

# %%
data.close()

# %%
for h5file in h5files:
    data = h5py.File(h5file)
    try:
        data['TVI/times']
    except:
        print(h5file)
    data.close()
# Out:
# /Users/torjushaukom/Documents/Studier/Masteroppgave/Strain_estimation/data/processed/mitral_point_labeled/p3/I599G5GA.h5
